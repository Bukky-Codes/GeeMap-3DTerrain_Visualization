# %%
import os
import geemap
import pvxarray
import xarray as xr

# %%
image = 'niger_nig.tif'
if not os.path.exists(image):
    print('error')

# %%
geemap.plot_raster(image, cmap='terrain', figsize=(15, 10))

# %%
Map = geemap.Map()
Map

# %%
Map.add_raster(image, palette ='terrain', layer_name='DEM')

# %%
geemap.plot_raster_3d('niger_nig.tif', factor=15, cmap='terrain', background='gray')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
